# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en_core_web_sm==2.1.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.1.0/en_core_web_sm-2.1.0.tar.gz#egg=en_core_web_sm==2.1.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.1.0/en_core_web_sm-2.1.0.tar.gz (11.1MB)
#     100% |████████████████████████████████| 11.1MB 4.3MB/s ta 0:00:01
# Installing collected packages: en-core-web-sm
#   Running setup.py install for en-core-web-sm ... done
# Successfully installed en-core-web-sm-2.1.0
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %% [markdown]
# Who do firms mention as their competitors, peers, customers, and suppliers? In this post, I extract named entities from the Business Description fields of Microsoft's annual report (Form 10-K) to answer this question. Named entities are defined by Wikipedia as real-world objects, "such as persons, locations, organizations, products, etc., that can be denoted with a proper name." There are many approaches and tools for named entity recognition (NER) and extraction. I will be using Python NLTK and SpaCy.

# %%
import nltk
import re
import os
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
#nltk.download("stopwords")
#nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/reggie/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %% [markdown]
# Let's start with Microsoft's 10-K from fiscal-year-ended 2018. And let's peek at the first 1,000 characters of it's Business description section ("Item 1").

# %%
text = open("../data/item1/msft-item1-2018","r").read()
text[:1000]
# Out:
# 'ITEM 1. BUSINESS\n\nGENERAL\n\nEmbracing Our Future\n\nMicrosoft is a technology company whose mission is to empower every person and every organization on the planet to achieve more. We strive to create local opportunity, growth, and impact in every country around the world. Our platforms and tools help drive small business productivity, large business competitiveness, and public-sector efficiency. They also support new startups, improve educational and health outcomes, and empower human ingenuity.\n\nWe continue to transform our business to lead in the new era of the intelligent cloud and intelligent edge. We bring technology and products together into experiences and solutions that unlock value for our customers. In this next phase of innovation, computing is more powerful and ubiquitous from the cloud to the edge. Artificial intelligence (“AI”) capabilities are rapidly advancing, fueled by data and knowledge of the world. Physical and virtual worlds are coming together to create richer exp'

# %%
Next, we'll tokenize the text and tag the various parts-of-speech.

# %%
## tokenize text
tokens = nltk.word_tokenize(text)
tokens_tagged = nltk.pos_tag(tokens)
tokens_tagged[:20]
# Out:
# [('ITEM', 'NNP'),
#  ('1.', 'CD'),
#  ('BUSINESS', 'NNP'),
#  ('GENERAL', 'NNP'),
#  ('Embracing', 'NNP'),
#  ('Our', 'PRP$'),
#  ('Future', 'NN'),
#  ('Microsoft', 'NNP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('technology', 'NN'),
#  ('company', 'NN'),
#  ('whose', 'WP$'),
#  ('mission', 'NN'),
#  ('is', 'VBZ'),
#  ('to', 'TO'),
#  ('empower', 'VB'),
#  ('every', 'DT'),
#  ('person', 'NN'),
#  ('and', 'CC')]

# %%
## Remove punctuation and tokenize
text_tokens = text.translate(str.maketrans('', '', string.punctuation)).lower().split()
text_tokens[:10]
# Out:
# ['item',
#  '1',
#  'business',
#  'general',
#  'embracing',
#  'our',
#  'future',
#  'microsoft',
#  'is',
#  'a']

# %% [raw]
# Next, we'll use a regular expression to identify noun phrase chunks. It will take the form of a rule that a noun phrase is an optional determiner (such as "the") followed by one or more adjectives and then a noun.

# %%
chunk_parser = nltk.RegexpParser(r"NP: {<DT>?<JJ>*<NN>}")
chunk_tokens = chunk_parser.parse(tokens_tagged[:20])
print(chunk_tokens)
# Out:
# (S
#   ITEM/NNP
#   1./CD
#   BUSINESS/NNP
#   GENERAL/NNP
#   Embracing/NNP
#   Our/PRP$
#   (NP Future/NN)
#   Microsoft/NNP
#   is/VBZ
#   (NP a/DT technology/NN)
#   (NP company/NN)
#   whose/WP$
#   (NP mission/NN)
#   is/VBZ
#   to/TO
#   empower/VB
#   (NP every/DT person/NN)
#   and/CC)

# %%
## remove stopwords
text_tokens2 = [word for word in text_tokens if word not in stopwords.words("english")]
text_tokens2[:50]
# Out:
# ['item',
#  '1',
#  'business',
#  'general',
#  'embracing',
#  'future',
#  'microsoft',
#  'technology',
#  'company',
#  'whose',
#  'mission',
#  'empower',
#  'every',
#  'person',
#  'every',
#  'organization',
#  'planet',
#  'achieve',
#  'strive',
#  'create',
#  'local',
#  'opportunity',
#  'growth',
#  'impact',
#  'every',
#  'country',
#  'around',
#  'world',
#  'platforms',
#  'tools',
#  'help',
#  'drive',
#  'small',
#  'business',
#  'productivity',
#  'large',
#  'business',
#  'competitiveness',
#  'publicsector',
#  'efficiency',
#  'also',
#  'support',
#  'new',
#  'startups',
#  'improve',
#  'educational',
#  'health',
#  'outcomes',
#  'empower',
#  'human']

# %%
from collections import Counter

# %%
tokens_count = Counter(text_tokens2)

# %%
tokens_count.most_common(50)
# Out:
# [('services', 100),
#  ('products', 57),
#  ('microsoft', 53),
#  ('business', 51),
#  ('devices', 46),
#  ('software', 45),
#  ('windows', 45),
#  ('cloud', 42),
#  ('customers', 39),
#  ('•', 37),
#  ('organizations', 37),
#  ('also', 36),
#  ('including', 34),
#  ('development', 33),
#  ('office', 32),
#  ('solutions', 31),
#  ('server', 31),
#  ('new', 30),
#  ('applications', 29),
#  ('president', 29),
#  ('sales', 25),
#  ('vice', 22),
#  ('marketing', 21),
#  ('product', 21),
#  ('gaming', 20),
#  ('provide', 20),
#  ('xbox', 20),
#  ('research', 19),
#  ('licenses', 19),
#  ('executive', 19),
#  ('productivity', 18),
#  ('support', 18),
#  ('operating', 18),
#  ('content', 18),
#  ('revenue', 18),
#  ('technology', 17),
#  ('computing', 17),
#  ('enterprise', 17),
#  ('commercial', 17),
#  ('designed', 17),
#  ('oems', 17),
#  ('system', 17),
#  ('information', 17),
#  ('licensing', 17),
#  ('agreements', 17),
#  ('tools', 16),
#  ('intelligent', 16),
#  ('experiences', 16),
#  ('management', 16),
#  ('online', 16)]

# %%
corpus = nlp(text)

# %%
len(corpus.ents)
# Out:
# 561

# %%
labels = [x.label_ for x in corpus.ents]
Counter(labels)
# Out:
# Counter({'ORG': 270,
#          'DATE': 69,
#          'CARDINAL': 49,
#          'PERSON': 73,
#          'ORDINAL': 11,
#          'PRODUCT': 8,
#          'WORK_OF_ART': 4,
#          'TIME': 1,
#          'FAC': 8,
#          'LOC': 18,
#          'GPE': 38,
#          'LAW': 3,
#          'EVENT': 1,
#          'NORP': 3,
#          'MONEY': 3,
#          'PERCENT': 2})

# %%
displacy.render(nlp(str(text)), jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">ITEM 1. BUSINESS</br></br>GENERAL</br></br>Embracing Our Future</br></br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Microsoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is a technology company whose mission is to empower every person and every organization on the planet to achieve more. We strive to create local opportunity, growth, and impact in every country around the world. Our platforms and tools help drive small business productivity, large business competitiveness, and public-sector efficiency. They also support new startups, improve educational and health outcomes, and empower human ingenuity.</br></br>We continue to transform our business to lead in the new era of the intelligent cloud and intelligent edge. We bring technology and products together into experiences and solutions that unlock value for our customers. In this next phase of innovation, computing is more powerful and ubiquitous from the cloud to the edge. Artificial intelligence (“AI”) capabilities are rapidly advancing, fueled by data and knowledge of the world. Physical and virtual worlds are coming together to create richer experiences that understand the context surrounding people, the things they use, the places they go, and their activities and relationships. A person’s experience with technology spans a multitude of devices and has become increasingly more natural and multi-sensory with voice, ink, and gaze interactions.</br></br>What We Offer</br></br>Founded in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     1975
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , we develop and support software, services, devices, and solutions that deliver new value for customers and help people and businesses realize their full potential.</br></br>Our products include operating systems; cross-device productivity applications; server applications; business solution applications; desktop and server management tools; software development tools; and video games. We also design, manufacture, and sell devices, including PCs, tablets, gaming and entertainment consoles, other intelligent devices, and related accessories.</br></br>We offer an array of services, including cloud-based solutions that provide customers with software, services, platforms, and content, and we provide solution support and consulting services. We also deliver relevant online advertising to a global audience.</br></br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br></br>PART I</br></br>Item 1</br></br> </br></br>The Ambitions That Drive Us</br></br>To achieve our vision, our research and development efforts focus on
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     three
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  interconnected ambitions:</br></br> </br></br>•</br></br>Reinvent productivity and business processes.</br></br> </br></br>•</br></br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Build
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  the intelligent cloud platform.</br></br> </br></br>•</br></br>Create more personal computing.</br></br>Reinvent Productivity and Business Processes</br></br>We are in a unique position to empower people and organizations to succeed in a rapidly evolving workplace. Computing experiences are evolving, no longer bound to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  device at a time. Instead, experiences are expanding to many devices as people move from home to work to on the go. These modern needs, habits, and expectations of our customers are motivating us to bring
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Microsoft Office 365
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , Windows platform, devices, including
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Microsoft Surface
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     third
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# -party applications into a more cohesive
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Microsoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     365
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  experience.</br></br>Our growth depends on securely delivering continuous innovation and advancing our leading productivity and collaboration tools and services, including
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Office
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; tex

# %%
## Using Stanford NER Tagger

# %%
from nltk.tag import StanfordNERTagger
from nltk.tokenize import word_tokenize

# %%
st = StanfordNERTagger("/home/reggie/Documents/stanford-ner-2018-10-16/classifiers/english.all.3class.distsim.crf.ser.gz",
                      "/home/reggie/Documents/stanford-ner-2018-10-16/stanford-ner.jar",
                      encoding="utf-8")

# %%
tokenized_text = word_tokenize(text[:10000])
classified_text = st.tag(tokenized_text)

print(classified_text)
# Out:
# [('ITEM', 'O'), ('1.', 'O'), ('BUSINESS', 'O'), ('GENERAL', 'O'), ('Embracing', 'O'), ('Our', 'O'), ('Future', 'O'), ('Microsoft', 'ORGANIZATION'), ('is', 'O'), ('a', 'O'), ('technology', 'O'), ('company', 'O'), ('whose', 'O'), ('mission', 'O'), ('is', 'O'), ('to', 'O'), ('empower', 'O'), ('every', 'O'), ('person', 'O'), ('and', 'O'), ('every', 'O'), ('organization', 'O'), ('on', 'O'), ('the', 'O'), ('planet', 'O'), ('to', 'O'), ('achieve', 'O'), ('more', 'O'), ('.', 'O'), ('We', 'O'), ('strive', 'O'), ('to', 'O'), ('create', 'O'), ('local', 'O'), ('opportunity', 'O'), (',', 'O'), ('growth', 'O'), (',', 'O'), ('and', 'O'), ('impact', 'O'), ('in', 'O'), ('every', 'O'), ('country', 'O'), ('around', 'O'), ('the', 'O'), ('world', 'O'), ('.', 'O'), ('Our', 'O'), ('platforms', 'O'), ('and', 'O'), ('tools', 'O'), ('help', 'O'), ('drive', 'O'), ('small', 'O'), ('business', 'O'), ('productivity', 'O'), (',', 'O'), ('large', 'O'), ('business', 'O'), ('competitiveness', 'O'), (',', 'O'), ('and', 'O'), ('public-sector', 'O'), ('efficiency', 'O'), ('.', 'O'), ('They', 'O'), ('also', 'O'), ('support', 'O'), ('new', 'O'), ('startups', 'O'), (',', 'O'), ('improve', 'O'), ('educational', 'O'), ('and', 'O'), ('health', 'O'), ('outcomes', 'O'), (',', 'O'), ('and', 'O'), ('empower', 'O'), ('human', 'O'), ('ingenuity', 'O'), ('.', 'O'), ('We', 'O'), ('continue', 'O'), ('to', 'O'), ('transform', 'O'), ('our', 'O'), ('business', 'O'), ('to', 'O'), ('lead', 'O'), ('in', 'O'), ('the', 'O'), ('new', 'O'), ('era', 'O'), ('of', 'O'), ('the', 'O'), ('intelligent', 'O'), ('cloud', 'O'), ('and', 'O'), ('intelligent', 'O'), ('edge', 'O'), ('.', 'O'), ('We', 'O'), ('bring', 'O'), ('technology', 'O'), ('and', 'O'), ('products', 'O'), ('together', 'O'), ('into', 'O'), ('experiences', 'O'), ('and', 'O'), ('solutions', 'O'), ('that', 'O'), ('unlock', 'O'), ('value', 'O'), ('for', 'O'), ('our', 'O'), ('customers', 'O'), ('.', 'O'), ('In', 'O'), ('this', 'O'), ('next', 'O'), ('phase', 'O'), ('of', 'O'), ('innovation', 'O'), (',', 'O'), ('computing', 'O'), ('is', 'O'), ('more', 'O'), ('powerful', 'O'), ('and', 'O'), ('ubiquitous', 'O'), ('from', 'O'), ('the', 'O'), ('cloud', 'O'), ('to', 'O'), ('the', 'O'), ('edge', 'O'), ('.', 'O'), ('Artificial', 'O'), ('intelligence', 'O'), ('(', 'O'), ('“', 'O'), ('AI', 'O'), ('”', 'O'), (')', 'O'), ('capabilities', 'O'), ('are', 'O'), ('rapidly', 'O'), ('advancing', 'O'), (',', 'O'), ('fueled', 'O'), ('by', 'O'), ('data', 'O'), ('and', 'O'), ('knowledge', 'O'), ('of', 'O'), ('the', 'O'), ('world', 'O'), ('.', 'O'), ('Physical', 'O'), ('and', 'O'), ('virtual', 'O'), ('worlds', 'O'), ('are', 'O'), ('coming', 'O'), ('together', 'O'), ('to', 'O'), ('create', 'O'), ('richer', 'O'), ('experiences', 'O'), ('that', 'O'), ('understand', 'O'), ('the', 'O'), ('context', 'O'), ('surrounding', 'O'), ('people', 'O'), (',', 'O'), ('the', 'O'), ('things', 'O'), ('they', 'O'), ('use', 'O'), (',', 'O'), ('the', 'O'), ('places', 'O'), ('they', 'O'), ('go', 'O'), (',', 'O'), ('and', 'O'), ('their', 'O'), ('activities', 'O'), ('and', 'O'), ('relationships', 'O'), ('.', 'O'), ('A', 'O'), ('person', 'O'), ('’', 'O'), ('s', 'O'), ('experience', 'O'), ('with', 'O'), ('technology', 'O'), ('spans', 'O'), ('a', 'O'), ('multitude', 'O'), ('of', 'O'), ('devices', 'O'), ('and', 'O'), ('has', 'O'), ('become', 'O'), ('increasingly', 'O'), ('more', 'O'), ('natural', 'O'), ('and', 'O'), ('multi-sensory', 'O'), ('with', 'O'), ('voice', 'O'), (',', 'O'), ('ink', 'O'), (',', 'O'), ('and', 'O'), ('gaze', 'O'), ('interactions', 'O'), ('.', 'O'), ('What', 'O'), ('We', 'O'), ('Offer', 'O'), ('Founded', 'O'), ('in', 'O'), ('1975', 'O'), (',', 'O'), ('we', 'O'), ('develop', 'O'), ('and', 'O'), ('support', 'O'), ('software', 'O'), (',', 'O'), ('services', 'O'), (',', 'O'), ('devices', 'O'), (',', 'O'), ('and', 'O'), ('solutions', 'O'), ('that', 'O'), ('deliver', 'O'), ('new', 'O'), ('value', 'O'), ('for', 'O'), ('customers', 'O'), ('and', 'O'), ('help', 'O'), ('people', ' ...

# %%
for item in classified_text:
    if item[1] != "O":
        print(item)
# Out:
# ('Microsoft', 'ORGANIZATION')
# ('Microsoft', 'ORGANIZATION')
# ('Microsoft', 'ORGANIZATION')
# ('Microsoft', 'ORGANIZATION')
# ('Office', 'ORGANIZATION')
# ('Microsoft', 'ORGANIZATION')
# ('Dynamics', 'ORGANIZATION')
# ('Microsoft', 'ORGANIZATION')
# ('Microsoft', 'ORGANIZATION')
# ('Microsoft', 'ORGANIZATION')
# ('LinkedIn', 'ORGANIZATION')
# ('Sales', 'ORGANIZATION')
# ('Navigator', 'ORGANIZATION')
# ('and', 'ORGANIZATION')
# ('Dynamics', 'ORGANIZATION')
# ('LinkedIn', 'ORGANIZATION')
# ('Recruiter', 'ORGANIZATION')
# ('Microsoft', 'ORGANIZATION')
# ('Azure', 'ORGANIZATION')
# ('Microsoft', 'ORGANIZATION')
# ('Azure', 'ORGANIZATION')
# ('Machine', 'ORGANIZATION')
# ('Learning', 'ORGANIZATION')
# ('Studio', 'ORGANIZATION')
# ('Azure', 'ORGANIZATION')
# ('Machine', 'ORGANIZATION')
# ('Learning', 'ORGANIZATION')
# ('Workbench', 'ORGANIZATION')
# ('Microsoft', 'ORGANIZATION')
# ('GitHub', 'ORGANIZATION')
# (',', 'ORGANIZATION')
# ('Inc.', 'ORGANIZATION')
# ('Cortana', 'PERSON')
# ('Mixer', 'PERSON')
